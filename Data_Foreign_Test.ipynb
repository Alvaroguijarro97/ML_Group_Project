# %% [markdown]
# <a href="https://colab.research.google.com/github/Alvaroguijarro97/ML_Group_Project/blob/main/Data_Foreign_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
# Upload the file into the notebook and set it as a dataframe
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-70a2db18-d04a-4685-bf51-c1c0492df339" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70a2db18-d04a-4685-bf51-c1c0492df339">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
foreign_data = pd.read_csv(io.BytesIO(uploaded['12521-0021_flat.csv']), encoding="windows_1258")

foreign_data.info()

foreign_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Statistik_Code              432 non-null    int64
#  1   Statistik_Label             432 non-null    object
#  2   Zeit_Code                   432 non-null    object
#  3   Zeit_Label                  432 non-null    object
#  4   Zeit                        432 non-null    object
#  5   1_Merkmal_Code              432 non-null    object
#  6   1_Merkmal_Label             432 non-null    object
#  7   1_Auspraegung_Code          432 non-null    int64
#  8   1_Auspraegung_Label         432 non-null    object
#  9   2_Merkmal_Code              432 non-null    object
#  10  2_Merkmal_Label             432 non-null    object
#  11  2_Auspraegung_Code          288 non-null    object
#  12  2_Auspraegung_Label         432 non-null    object
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/Alvaroguijarro97/ML_Group_Project/blob/main/upload_csv_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #This is an example on how to upload a csv with multilevel Header and Index

# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f074a40d-ed62-46d7-8c2b-4d1c18fab8ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f074a40d-ed62-46d7-8c2b-4d1c18fab8ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# in order to make this work you need to download ths csv fiel with the index incouded
import io
index_foreign_data_by_state_sorted = pd.read_csv(io.BytesIO(uploaded['index_foreign_data_by_state_sorted.csv']), encoding="windows_1258", index_col= [0], header=[0,1])
index_foreign_data_by_state_sorted.rename(index={"Baden-WĂ¼rttemberg": "Baden-Württemberg"})
# Out:
#                                 Foreign_Population                      \
# number                                           1         2         3
# State of residence (in Germany)
# Baden-Württemberg                         0.000008  0.000031  0.000084
# Bavaria                                   0.000013  0.000027  0.000086
# Berlin                                    0.000037  0.000135  0.000146
# Brandenburg                               0.000004  0.000008  0.000024
# Bremen                                    0.000015  0.000045  0.000067
# Hamburg                                   0.000011  0.000033  0.000098
# Hesse                                     0.000014  0.000036  0.000085
# Lower Saxony                              0.000005  0.000015  0.000033
# Mecklenburg Western Pomerania             0.000003  0.000009  0.000032
# Northrhine-Westphalia                     0.000010  0.000048  0.000070
# Rhineland Palatinate                      0.000014  0.000025  0.000055
# ...
